# %% [markdown]
# # Linking it situ phenological observations with climate data
#
# The following example leverages the [NEON Data](http://data.neonscience.org/data-api) and [Google Earth Engine](https://developers.google.com/earth-engine/) APIs to link in situ phenological observations with climate data.
#
# We'll use the `requests` module to handle sending and receiving data from the NEON Data API and the `ee` module to handle calls to the Earth Engine API. Along the way, we'll invoke R for visualization purposes (i.e., using [`ggplot2`](https://github.com/tidyverse/ggplot2) and [`leaflet`](https://github.com/rstudio/leaflet) packages). We'll also define some variables to use a few times.

# %%
# %load_ext rpy2.ipython

# %%
import requests
import json
import ee
from pandas.io.json import json_normalize
import pandas as pd


ee.Initialize()  # initialize the Earth Engine object.


PRODUCTCODE = "DP1.10055.001"  # the product code for plant phenology observations
SERVER = "http://data.neonscience.org/api/v0/"  # the current server address

# %% [markdown]
# First, we'll send a request to NEON's `/products` endpoint to get some information about what's available there. The response is in JSON format, which we can view using `json.dumps` for formatting.

# %%
product_response = requests.get(SERVER + 'products/' + PRODUCTCODE)
product_response_json = product_response.json()
# print(json.dumps(product_response_json, indent=2))

# %% [markdown]
# We'll grab the information available under `data -> siteCodes` to determine which sites have generated phenology data. The `locations/` endpoints contains the relevant location information.

# %%
data_products = product_response_json['data']['siteCodes']
site_codes = [d['siteCode'] for d in data_products]
# print(site_codes)
# Out:
# [u'JORN', u'OAES', u'DSNY', u'OSBS', u'JERC', u'SCBI', u'STER', u'MOAB', u'WOOD', u'SERC', u'BART', u'UNDE', u'UKFS', u'TALL', u'CPER', u'ORNL', u'ONAQ', u'GRSM', u'HARV']

# %% [markdown]
# Let's pull location information (i.e., longitude/latitude) for each site.

# %%
metadata_fields = ['siteCode', 'locationDescription', 'locationElevation', 
                   'locationDecimalLongitude', 'locationDecimalLatitude']

site_metadata = []
for site_code in site_codes:
    location_response = requests.get(SERVER + 'locations/' + site_code)
    location_response_json = location_response.json()
#     print(json_normalize(location_response_json['data']).columns.values)
    site_metadata.append(json_normalize(location_response_json['data']).loc[:, metadata_fields])
site_metadata = pd.concat(site_metadata, axis=0)
# print(site_metadata)
# Out:
#   siteCode                                locationDescription  \
# 0     JORN                     Jornada LTER Site, RELOCATABLE
# 0     OAES    Klemme Range Research Station Site, RELOCATABLE
# 0     DSNY       Disney Wilderness Preserve Site, RELOCATABLE
# 0     OSBS       Ordway-Swisher Biological Station Site, CORE
# 0     JERC  Jones Ecological Research Center Site, RELOCAT...
# 0     SCBI  Smithsonian Conservation Biology Institute Sit...
# 0     STER                         Sterling Site, RELOCATABLE
# 0     MOAB                             Moab Site, RELOCATABLE
# 0     WOOD                               Woodworth Site, CORE
# 0     SERC  Smithsonian Environmental Research Center Site...
# 0     BART     Bartlett Experimental Forest Site, RELOCATABLE
# 0     UNDE                                  UNDERC Site, CORE
# 0     UKFS  The University of Kansas Field Station Site, R...
# 0     TALL               Talladega National Forest Site, CORE
# 0     CPER       Central Plains Experimental Range Site, CORE
# 0     ORNL                               Oak Ridge Site, CORE
# 0     ONAQ                             Onaqui-Ault Site, CORE
# 0     GRSM  Great Smoky Mountains National Park Site, RELO...
# 0     HARV                          Harvard Forest Site, CORE
#
#    locationElevation  locationDecimalLongitude  locationDecimalLatitude
# 0        1329.000000               -106.842540                32.590680
# 0         520.000000                -99.058779                35.410599
# 0          20.000000                -81.436190                28.125050
# 0          46.000000                -81.993431                29.689282
# 0          47.000000                -84.468623                31.194839
# 0         353.089464                -78.139494                38.892925
# 0        1364.000000               -103.029290                40.461894
# 0        1799.000000               -109.388273                38.248283
# 0         591.250000                -99.241334                47.128200
# 0          10.000000                -76.560014                38.890131
# 0         275.000000                -71.287375                44.063869
# 0         522.000000                -89.537254                46.233910
# 0         322.000000                -95.192150                39.040431
# 0         166.859712                -87.393259                32.950470
# 0        1648.000000               -104.745600                40.815530
# 0         344.000000                -84.282588                35.964128
# 0        1656.000000               -112.452452                40.177599
# 0                NaN                       NaN                      NaN
# 0         349.000000                -72.172650                42.536911

# %% [markdown]
# Find out what months of data are available for each site. We'll need the information that's under `data -> siteCodes -> availableMonths`.

# %%
site_x_month = json_normalize(data_products, 'availableMonths', 'siteCode')
site_x_month = site_x_month.rename(index=int, columns={0: "obsDate"})
# print(site_x_month)

# %% [markdown]
# Create an interactive map from the site locations, in which the radius of each marker is scaled according to the number of samples available for a given site.

# %%
# %%R -i site_metadata site_x_month -o pheno_obs_counts
#
# library(dplyr)
# library(leaflet)
#
# mapbox_light_template <-
#   'https://api.mapbox.com/styles/v1/mapbox/light-v9/tiles/256/{z}/{x}/{y}?access_token=pk.eyJ1IjoibHphY2htYW5uIiwiYSI6ImNpcW1oODczZTAwcjBnc2pmaGRhYjVudHIifQ.LeGAHvHXv36-vorTmuNtSg'
#
#
# pheno_obs_counts <- site_metadata %>%
#     left_join(site_x_month, by = 'siteCode') %>%
#     group_by(siteCode) %>%
#     summarise(n=n(), site_desc=locationDescription[1],
#               lon=locationDecimalLongitude[1], lat=locationDecimalLatitude[1]) %>%
#     na.omit %>%
#     as.data.frame
# # print(pheno_obs_counts)
#
# leaf <- leaflet() %>%
#   # Base groups.
#   addTiles(urlTemplate=mapbox_light_template, group='Light') %>%
#   # Overlay groups.
#   addCircleMarkers(data=pheno_obs_counts,
#                    lng=~lon, lat=~lat, popup=~site_desc, radius=~n) %>%
#   addScaleBar('bottomright')
# leaf

# %% [markdown]
# Extract time series SI-x data to site locations using Earth Engine.

# %%
site_summary_pd_df = pd.DataFrame(pheno_obs_counts)

ee_features = []
for i in range(site_summary_pd_df.shape[0]):
    point_data = site_summary_pd_df.iloc[0, :]
    point = ee.Geometry.Point(list(point_data.loc[['lon', 'lat']]))
    ee_feature = ee.Feature(point, {'siteCode': point_data.loc['siteCode']})
    ee_features.append(ee_feature)
ee_feature_coll = ee.FeatureCollection(ee_features)
# print(ee_feature_coll.getInfo())


SIx_asset_path = 'users/LZachmann/SI-x_v6_0_0'
SIx = ee.ImageCollection(SIx_asset_path)
# print(SIx.size().getInfo()) 

def extract_six_to_point(image):
    timestep_fc = image.reduceRegions(collection=ee_feature_coll, reducer=ee.Reducer.first(), scale=250)
    return timestep_fc
ee_results = SIx.map(extract_six_to_point).flatten()
# print(ee_results.getInfo())
# Out:
# {u'type': u'FeatureCollection', u'features': [{u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_0', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_1', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_2', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_3', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_4', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_5', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_6', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_7', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_8', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_9', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_10', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_11', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_12', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_13', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_14', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_15', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_16', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1981_17', u'properties': {u'siteCode': u'BART', u'b1': 98.0, u'b2': 141.0}}, {u'geometry': {u'type': u'Point', u'geodesic': True, u'coordinates': [-71.287375, 44.0638694444]}, u'type': u'Feature', u'id': u'si_x_1982_0', u'properties': {u'siteC ...
